# %% [markdown]
# # Use Cases for our Model

# %% [markdown]
# ## Load Dependencies

# %%
#import libraries
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv, dotenv_values
import re
import pickle
import pandas as pd
import numpy as np

# %%
load_dotenv()
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")
redirect_url = os.getenv("REDIRECT_URL")

# %%
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
#extract uri function
def extract_uri(url):
    pattern = r'(track|album|artist|playlist)/([a-zA-Z0-9]{22})' #spotify uri is a 22 char alphanumeric identifier
    
    # Try to find a match in the URL
    match = re.search(pattern, url)

    # If a match is found, return the Spotify ID
    if match:
        return match.group(2)
    else:
        return None

# %%
#load the model
file = pickle.load(open("model.pk1","rb"))
model = file['model']
feature_list = file['features']
scaler = file['scaler']

# %%
def preprocess(df):
    from sklearn.preprocessing import MinMaxScaler
    features = df[feature_list]
    scaled_df = scaler.transform(features)
    features = pd.DataFrame(scaled_df, columns=features.columns)
    return features

# %%
def get_playlist_tracks(playlist_id):
    track_ids = []
    track_names =[]
    track_artists = []
    tracks = sp.playlist_tracks(playlist_id)['items']
    for track in tracks:
        track_ids.append(track['track']['id'])
        track_names.append(track['track']['name'])
        track_artists.append(track['track']['artists'])
    return track_ids, track_names, track_artists

# %%
def get_album_tracks(album_id):
    track_ids = []
    track_names = []
    track_artists = []
    tracks = sp.album_tracks(album_id)['items']
    for track in tracks:
        track_ids.append(track['id'])
        track_names.append(track['name'])
        track_artists.append(track['artists'])
    return track_ids, track_names, track_artists

# %%
#partition function
def partition(lst, size):
    split = [lst[i:i+size] for i in range(0,len(lst),size)]
    return split

# %%
def get_features(track_ids):
    part = partition(track_ids,100) #list of partitioned tracks
    audio_features = []
    for p in part:
        audio_features.extend(sp.audio_features(p))
    return audio_features

# %% [markdown]
# ## 1. Take in spotify collection URL and classify the collection

# %% [markdown]
# ### Enter spotify playlist and get classification

# %%
# adding column "energetic"
def is_energetic(x):
    return 'Energetic' if x==1 else 'Not Energetic'


def get_playlist_class(url):
    id = extract_uri(url)
    track_ids, track_names, track_artists = get_playlist_tracks(id)

    #finding first artists
    first_artist = []
    for i in range(0,len(track_artists)):
        first_artist.append(track_artists[i][0]['name'])

    
    #making dataframe
    df = pd.DataFrame(get_features(track_ids))
    df.insert(loc=0, column='track_id', value=track_ids)
    df.insert(loc=1, column='track_name', value=track_names)
    df.insert(loc=2, column='first_artist', value=first_artist)

    #extract features
    features = preprocess(df)
    y_pred = model.predict(features)

    df['pred'] = pd.Series(y_pred)
    df['class'] = df['pred'].apply(lambda x: is_energetic(x))


    # adding column "energetic"


    #we will make a classification report
    energetic_tracks = df[['first_artist','track_name']][df.pred==1]
    prop = len(energetic_tracks)/len(df)

    return {'energetic_tracks': energetic_tracks, 'prop': prop, 'dataframe':df}

# %% [markdown]
# ### Check with a mostly energetic playlist

# %%
report = get_playlist_class("https://open.spotify.com/playlist/3lE3qloHpUZbGz0IpT1xZk?si=8e984439c78c4238")
report['dataframe']
# Out:
#                   track_id                             track_name  \
# 0   2EK48RuuE8HHMDzD2rEDqL                                  Siren
# 1   60M8FSYZP8MA0Wy2huOADL                               LA DI DA
# 2   3As0OA5B06BxLfADvYyG8L                           Stay Tonight
# 3   7rXcCpIAoOUCydkVDMcoPV                                   INVU
# 4   37ZtpRBkHcaq6hHy0X98zn                        I CAN'T STOP ME
# ..                     ...                                    ...
# 95  54HsCR7lJJdwxmEnTY1JfF                          Dun Dun Dance
# 96  5i5WNh302rkoveunUdZwG2                              Starlight
# 97  5z2Zf4ORrWDSSJCgDrhz29                                 Fiesta
# 98  4N2pGeYYsA7zMOCkXejMd8                   DON′T ASK DON′T TELL
# 99  2Gceplet3jzhweUib54mhf  PROMISE (for UNICEF Promise Campaign)
#
#     first_artist  danceability  energy  key  loudness  mode  speechiness  \
# 0          SUNMI         0.610   0.905    9    -3.686     0       0.0369
# 1       EVERGLOW         0.477   0.850    3    -1.486     0       0.0911
# 2       CHUNG HA         0.625   0.831    2    -2.186     0       0.0560
# 3        TAEYEON         0.599   0.816   11    -3.412     0       0.0556
# 4          TWICE         0.657   0.880   10    -3.672     0       0.1020
# ..           ...           ...     ...  ...       ...   ...          ...
# 95    OH MY GIRL         0.647   0.957    1    -0.384     0       0.0819
# 96  Dreamcatcher         0.548   0.898    6    -3.945     0       0.0484
# 97         VIVIZ         0.687   0.924    2    -2.443     1       0.0639
# 98      EVERGLOW         0.763   0.828    1    -3.034     0       0.0458
# 99      EVERGLOW         0.533   0.820    6    -2.284     1       0.0581
#
#     acousticness  ...    tempo            type                      id  \
# 0        0.01420  ...  122.012  audio_features  2EK48RuuE8HHMDzD2rEDqL
# 1        0.00108  ...  163.845  audio_features  60M8FSYZP8MA0Wy2huOADL
# 2        0.20300  ...  121.025  audio_features  3As0OA5B06BxLfADvYyG8L
# 3        0.09110  ...  106.962  audio_features  7rXcCpIAoOUCydkVDMcoPV
# 4        0.12100  ...  150.084  audio_features  37ZtpRBkHcaq6hHy0X98zn
# ..           ...  ...      ...             ...                     ...
# 95       0.16900  ...  114.968  audio_features  54HsCR7lJJdwxmEnTY1JfF
# 96       0.00244  ...  149.970  audio_features  5i5WNh302rkoveunUdZwG2
# 97       0.10600  ...  116.954  audio_features  5z2Zf4ORrWDSSJCgDrhz29
# 98       0.06880  ...  118.044  audio_features  4N2pGeYYsA7zMOCkXejMd8
# 99       0.00335  ...  155.991  audio_features  2Gceplet3jzhweUib54mhf
#
#                                      uri  \
# 0   spotify:track:2EK48RuuE8HHMDzD2rEDqL
# 1   spotify:track:60M8FSYZP8MA0Wy2huOADL
# 2   spotify:track:3As0OA5B06BxLfADvYyG8L
# 3   spotify:track:7rXcCpIAoOUCydkVDMcoPV
# 4   spotify:track:37ZtpRBkHcaq6hHy0X98zn
# ..                                   ...
# 95  spotify:track:54HsCR7lJJdwxmEnTY1JfF
# 96  spotify:track:5i5WNh302rkoveunUdZwG2
# 97  spotify:track:5z2Zf4ORrWDSSJCgDrhz29
# 98  spotify:track:4N2pGeYYsA7zMOCkXejMd8
# 99  spotify:track:2Gceplet3jzhweUib54mhf
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/2EK48RuuE8HH...
# 1   https://api.spotify.com/v1/tracks/60M8FSYZP8MA...
# 2   https://api.spotify.com/v1/tracks/3As0OA5B06Bx...
# 3   https://api.spotify.com/v1/tracks/7rXcCpIAoOUC...
# 4   https://api.spotify.com/v1/tracks/37ZtpRBkHcaq...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/54HsCR7lJJdw...
# 96  https://api.spotify.com/v1/tracks/5i5WNh302rko...
# 97  https://api.spotify.com/v1/tracks/5z2Zf4ORrWDS...
# 98  https://api.spotify.com/v1/tracks/4N2pGeYYsA7z...
# 99  https://api.spotify.com/v1/tracks/2Gceplet3jzh...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/2EK4...      199134
# 1   https://api.spotify.com/v1/audio-analysis/60M8...      210893
# 2   https://api.spotify.com/v1/audio-analysis/3As0...      217239
# 3   https://api.spotify.com/v1/audio-analysis/7rXc...      204973
# 4   https://api.spotify.com/v1/audio-analysis/37Zt...      205493
# ..                                                ...         ...
# 95  https://api.spotify.com/v1/audio-analysis/54Hs...      220560
# 96  https://api.spotify.com/v1/audio-analysis/5i5W...      199093
# 97  https://api.spotify.com/v1/audio-analysis/5z2Z...      211773
# 98  https://api.spotify.com/v1/audio-analysis/4N2p...      208320
# 99  https://api.spotify.com/v1/audio-analysis/2Gce...      214440
#
#    time_signature pred      class
# 0               4    1  Energetic
# 1               4    1  Energetic
# 2               4    1  Energetic
# 3               4    1  Energetic
# 4               4    1  Energetic
# ..            ...  ...        ...
# 95              4    1  Energetic
# 96              4    1  Energetic
# 97              4    1  Energetic
# 98              4    1  Energetic
# 99              4    1  Energetic
#
# [100 rows x 23 columns]

# %%
report['energetic_tracks']
# Out:
#     first_artist                             track_name
# 0          SUNMI                                  Siren
# 1       EVERGLOW                               LA DI DA
# 2       CHUNG HA                           Stay Tonight
# 3        TAEYEON                                   INVU
# 4          TWICE                        I CAN'T STOP ME
# ..           ...                                    ...
# 95    OH MY GIRL                          Dun Dun Dance
# 96  Dreamcatcher                              Starlight
# 97         VIVIZ                                 Fiesta
# 98      EVERGLOW                   DON′T ASK DON′T TELL
# 99      EVERGLOW  PROMISE (for UNICEF Promise Campaign)
#
# [98 rows x 2 columns]

# %%
report['prop']
# Out:
# 0.98

# %% [markdown]
# ### Enter Spotify Album and get classification

# %%
def get_album_class(url):
    id = extract_uri(url)
    track_ids, track_names, track_artists = get_album_tracks(id)
    #finding first artists
    first_artist = []
    for i in range(0,len(track_artists)):
        first_artist.append(track_artists[i][0]['name'])

    
    #making dataframe
    df = pd.DataFrame(get_features(track_ids))
    df.insert(loc=0, column='track_id', value=track_ids)
    df.insert(loc=1, column='track_name', value=track_names)
    df.insert(loc=2, column='first_artist', value=first_artist)

    #extract features
    features = preprocess(df)
    y_pred = model.predict(features)

    df['pred'] = pd.Series(y_pred)
    df['class'] = df['pred'].apply(lambda x: is_energetic(x))


    # adding column "energetic"


    #we will make a classification report
    energetic_tracks = df[['first_artist','track_name']][df.pred==1]
    prop = len(energetic_tracks)/len(df)

    return {'energetic_tracks': energetic_tracks, 'prop': prop, 'dataframe':df}

# %% [markdown]
# #### Check with a mostly energetic album

# %%
album = get_album_class("https://open.spotify.com/album/6al2VdKbb6FIz9d7lU7WRB?si=bwvAuuaoRlilrZRox1Ys_A")

# %%
album['dataframe'].head()
# Out:
#                  track_id     track_name first_artist  danceability  energy  \
# 0  1IthE5GNiRzFN5CVaCa445    Born Singer          BTS         0.602   0.841
# 1  27S8iOXD7Z58yvJtyk2S9j  No More Dream          BTS         0.438   0.864
# 2  2GEnvQgSJhedm2sqZlOP8o            N.O          BTS         0.597   0.909
# 3  0vMk4IrUfSJQkhwZnVX6us     Boy In Luv          BTS         0.492   0.931
# 4  0Q53fuiKLGjDKD7Mme7EoQ         Danger          BTS         0.734   0.848
#
#    key  loudness  mode  speechiness  acousticness  ...    tempo  \
# 0    8    -3.334     0        0.109      0.035400  ...  157.937
# 1    2    -5.185     1        0.470      0.011800  ...  167.898
# 2   11    -4.500     0        0.160      0.044300  ...  146.870
# 3    9    -3.837     0        0.297      0.002440  ...  166.071
# 4    1    -4.433     1        0.102      0.000913  ...  112.021
#
#              type                      id  \
# 0  audio_features  1IthE5GNiRzFN5CVaCa445
# 1  audio_features  27S8iOXD7Z58yvJtyk2S9j
# 2  audio_features  2GEnvQgSJhedm2sqZlOP8o
# 3  audio_features  0vMk4IrUfSJQkhwZnVX6us
# 4  audio_features  0Q53fuiKLGjDKD7Mme7EoQ
#
#                                     uri  \
# 0  spotify:track:1IthE5GNiRzFN5CVaCa445
# 1  spotify:track:27S8iOXD7Z58yvJtyk2S9j
# 2  spotify:track:2GEnvQgSJhedm2sqZlOP8o
# 3  spotify:track:0vMk4IrUfSJQkhwZnVX6us
# 4  spotify:track:0Q53fuiKLGjDKD7Mme7EoQ
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1IthE5GNiRzF...
# 1  https://api.spotify.com/v1/tracks/27S8iOXD7Z58...
# 2  https://api.spotify.com/v1/tracks/2GEnvQgSJhed...
# 3  https://api.spotify.com/v1/tracks/0vMk4IrUfSJQ...
# 4  https://api.spotify.com/v1/tracks/0Q53fuiKLGjD...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1Ith...      238628
# 1  https://api.spotify.com/v1/audio-analysis/27S8...      222067
# 2  https://api.spotify.com/v1/audio-analysis/2GEn...      209752
# 3  https://api.spotify.com/v1/audio-analysis/0vMk...      231384
# 4  https://api.spotify.com/v1/audio-analysis/0Q53...      245810
#
#   time_signature pred      class
# 0              4    1  Energetic
# 1              4    1  Energetic
# 2              4    1  Energetic
# 3              4    1  Energetic
# 4              4    1  Energetic
#
# [5 rows x 23 columns]

# %%
album['energetic_tracks']
# Out:
#    first_artist                                    track_name
# 0           BTS                                   Born Singer
# 1           BTS                                 No More Dream
# 2           BTS                                           N.O
# 3           BTS                                    Boy In Luv
# 4           BTS                                        Danger
# 5           BTS                                      I NEED U
# 6           BTS                                           RUN
# 7           BTS                             Burning Up (FIRE)
# 8           BTS                           Blood Sweat & Tears
# 9           BTS                                    Spring Day
# 10          BTS                                           DNA
# 11          BTS                                     FAKE LOVE
# 12          BTS                                          IDOL
# 13          BTS                   Boy With Luv (Feat. Halsey)
# 14          BTS                                            ON
# 15          BTS                                      Dynamite
# 17          BTS                                        Butter
# 18          BTS                                   Yet To Come
# 19          BTS                                       Run BTS
# 20          BTS                               Intro : Persona
# 21          BTS                                          Stay
# 22          BTS                                          Moon
# 24          BTS                             Trivia 轉 : Seesaw
# 25          BTS  BTS Cypher PT.3 : KILLER (Feat. Supreme Boi)
# 26          BTS                                   Outro : Ego
# 27          BTS                                           Her
# 28          BTS                                        Filter
# 32          BTS                                      Euphoria
# 33          BTS                                        Dimple

# %%
album['prop']
# Out:
# 0.8285714285714286

# %% [markdown]
# #### Check with a non energetic album

# %%
album2 = get_album_class("https://open.spotify.com/album/12UGkXT4z3ajgq6xheCGDk?si=0lHB1uVCT06mxtHGZDUpoQ")
album2['dataframe']
# Out:
#                  track_id                     track_name  \
# 0  7cs7MLtAWvsdf3w5kBvfK2  Nothing's Gonna Hurt You Baby
# 1  73ptBTOgUcD3Wyrq0B9eAW              I'm a Firefighter
# 2  5DZNSYxhFA1WA9WEJg9TNY                Dreaming of You
# 3  3YL4zMqcyFu0OfLI1sZ66Z                    Starry Eyes
#
#            first_artist  danceability  energy  key  loudness  mode  \
# 0  Cigarettes After Sex         0.508   0.330    4   -14.071     1
# 1  Cigarettes After Sex         0.361   0.300    7   -13.657     1
# 2  Cigarettes After Sex         0.298   0.398    7   -14.911     1
# 3  Cigarettes After Sex         0.419   0.362    2   -15.320     1
#
#    speechiness  acousticness  ...    tempo            type  \
# 0       0.0265         0.259  ...   96.818  audio_features
# 1       0.0335         0.483  ...  114.941  audio_features
# 2       0.0365         0.549  ...   64.135  audio_features
# 3       0.0337         0.453  ...  100.264  audio_features
#
#                        id                                   uri  \
# 0  7cs7MLtAWvsdf3w5kBvfK2  spotify:track:7cs7MLtAWvsdf3w5kBvfK2
# 1  73ptBTOgUcD3Wyrq0B9eAW  spotify:track:73ptBTOgUcD3Wyrq0B9eAW
# 2  5DZNSYxhFA1WA9WEJg9TNY  spotify:track:5DZNSYxhFA1WA9WEJg9TNY
# 3  3YL4zMqcyFu0OfLI1sZ66Z  spotify:track:3YL4zMqcyFu0OfLI1sZ66Z
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7cs7MLtAWvsd...
# 1  https://api.spotify.com/v1/tracks/73ptBTOgUcD3...
# 2  https://api.spotify.com/v1/tracks/5DZNSYxhFA1W...
# 3  https://api.spotify.com/v1/tracks/3YL4zMqcyFu0...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7cs7...      286293
# 1  https://api.spotify.com/v1/audio-analysis/73pt...      271019
# 2  https://api.spotify.com/v1/audio-analysis/5DZN...      322219
# 3  https://api.spotify.com/v1/audio-analysis/3YL4...      206000
#
#   time_signature pred          class
# 0              4    0  Not Energetic
# 1              4    0  Not Energetic
# 2              3    0  Not Energetic
# 3              4    0  Not Energetic
#
# [4 rows x 23 columns]

# %%
album2['prop']
# Out:
# 0.0

# %% [markdown]
# ## 2. Find energetic songs from Spotify collections & generate a playlist
# - Playlist
# - Albums
# - Artist Discographies

# %% [markdown]
# ## Other thoughts:
#
# One can also use Oauth 2.0 Authorization flow for getting user's private content's access tokens from Spotify WEB API. This process is simple but require us to use Flask and HTML to provide server functionalities. With that, one can develop this additional functionality:
#
# ####  Find energetic songs from User collections & generate a playlist
# - User Liked Songs
# - User Playlists
# - User Listening History
