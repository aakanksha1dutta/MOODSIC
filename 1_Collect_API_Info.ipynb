# %% [markdown]
# # Collecting Information and Audio Features into a Dataframe

# %% [markdown]
# ## Importing Libaries

# %% [markdown]
# First we import the libraries necessary for using the Spotify API. Fortunately, Spotify has created an API wrapper called `spotipy` which allows us to interact with their API from a top level.
#
# We have two options for interacting with their API: Authorization Flow and Client Credentials. The Authorization flow is used when we need personal information from a Spotify user like their playlists, likes etc. Client Credentials flow is used to pull general information about Spotify's tracks, playlists etc. We will use the _Client Credentials_ flow.

# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv, dotenv_values

# %% [markdown]
# The dotenv library helps us load our environment variables. You can create your environment variables in a `.env` file.

# %% [markdown]
# Now, we have created a `.env` file in our local machines which has our API information like Client_ID, Client_Secret and Redirect_URL. You can create a similar file in the same directory that has this file. The template for the file is given below for your convenience. Save the file as `.env`
#
# ```
#     CLIENT_ID="your_client_id_here"
#     CLIENT_SECRET="your_client_secret_here"
#     REDIRECT_URL="your_redirect_url_here"
#
# ```

# %% [markdown]
# ## Loading environment variables and storing them

# %%
load_dotenv()
# Out:
# True

# %%
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")
redirect_url = os.getenv("REDIRECT_URL")

# %% [markdown]
# ## Creating an API session

# %%
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# ## Extracting information from the API

# %%
#we are using playlists from two categories - mood and toplists
toplists = sp.category_playlists(category_id="toplists", limit=30)
mood = sp.category_playlists(category_id="mood", limit=30)

#extract playlist information like playlist name and id
#will be used for extracting songs from each playlists and their audio features
def get_playlist_info():
    playlist_lists = []
    for playlist in toplists['playlists']['items']:
        playlist_id = playlist['id']
        playlist_lists.append(playlist_id)

    for playlist in mood['playlists']['items']:
        playlist_id = playlist['id']
        playlist_lists.append(playlist_id)
    
    return playlist_lists

# %% [markdown]
# Since there is a limit in Spotify WEB API for the number of requests, we are better off first collecting all the track ids in a single list.
# Then we can partiton it into sublists with 100 track ids (we are allowed to fetch features for a max of 100 ids at a time). This will allow us to use a single request for multiple track ids.

# %%
#extract songs from a playlist and return a list of rows that can be inserted into a dataframe
def get_playlist_tracks(playlist_id):
    track_ids = []
    track_names =[]
    track_artists = []
    tracks = sp.playlist_tracks(playlist_id)['items']
    for track in tracks:
        track_ids.append(track['track']['id'])
        track_names.append(track['track']['name'])
        track_artists.append(track['track']['artists'])
    return track_ids, track_names, track_artists
        
#extract songs from all playlist 
def extract_track_ids(playlist_lists):
    all_track_ids = []
    all_track_names = []
    all_track_artists = []
    for playlist in playlist_lists:
        track_ids, track_names, track_artists = get_playlist_tracks(playlist)
        all_track_ids.extend(track_ids)
        all_track_names.extend(track_names)
        all_track_artists.extend(track_artists)
        
    return all_track_ids, all_track_names, all_track_artists

#partition function
def partition(lst, size):
    split = [lst[i:i+size] for i in range(0,len(lst),size)]
    return split

# %%
#getting necessary columns
playlist_ids = get_playlist_info() #list of playlist ids
track_ids, track_names, track_artists = extract_track_ids(playlist_ids)

# %%
artists = []
for i in range(0,len(track_artists)):
    artists.append(track_artists[i][0]['name'])

# %%
part = partition(track_ids,100) #list of partitioned tracks
audio_features = []
for p in part:
    audio_features.extend(sp.audio_features(p))

# %%
#checking if all lengths are same
print("No of artists: ", len(artists))
print("No. of track names: ", len(track_names))
print("No of track ids: ", len(track_ids))
print("No. of tracks with audio features: ", len(audio_features))
# Out:
# No of artists:  3127
# No. of track names:  3127
# No of track ids:  3127
# No. of tracks with audio features:  3127

# %% [markdown]
# ### All seem to be well. We can now collect it into a Pandas dataframe.

# %% [markdown]
# ## Collecting extracted information in a Pandas dataframe

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(audio_features)
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.928   0.458   11    -6.751     1       0.1870        0.0175
# 1         0.943   0.558    2    -4.911     1       0.0568        0.0026
# 2         0.750   0.733    6    -3.180     0       0.0319        0.2560
# 3         0.559   0.551    5    -7.231     1       0.1320        0.1410
# 4         0.628   0.523   11    -8.307     0       0.0946        0.7010
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000446    0.1180    0.242  144.995  audio_features
# 1          0.000002    0.0937    0.606  104.983  audio_features
# 2          0.000000    0.1140    0.844  111.018  audio_features
# 3          0.000000    0.1100    0.392  143.008  audio_features
# 4          0.002740    0.2190    0.416  169.982  audio_features
#
#                        id                                   uri  \
# 0  1a73gcEg6h6Re6hHXoVltJ  spotify:track:1a73gcEg6h6Re6hHXoVltJ
# 1  4xhsWYTOGcal8zt0J161CU  spotify:track:4xhsWYTOGcal8zt0J161CU
# 2  3rUGC1vUpkDG9CZFHMur1t  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3  4iZ4pt7kvcaH6Yo8UoZ4s2  spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2
# 4  5mjYQaktjmjcMKcUIcqz4s  spotify:track:5mjYQaktjmjcMKcUIcqz4s
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1a73gcEg6h6R...
# 1  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 2  https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3  https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH...
# 4  https://api.spotify.com/v1/tracks/5mjYQaktjmjc...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1a73...       172138
# 1  https://api.spotify.com/v1/audio-analysis/4xhs...       138411
# 2  https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# 3  https://api.spotify.com/v1/audio-analysis/4iZ4...       201800
# 4  https://api.spotify.com/v1/audio-analysis/5mjY...       172965
#
#    time_signature
# 0               4
# 1               4
# 2               1
# 3               4
# 4               4

# %%
#adding other columns
df.insert(loc=0, column='track_ids', value=track_ids)
df.insert(loc=1, column='track_name', value=track_names)
df.insert(loc=2, column='artists', value=artists)
df.head()
# Out:
#                 track_ids   track_name      artists  danceability  energy  \
# 0  1a73gcEg6h6Re6hHXoVltJ         FTCU  Nicki Minaj         0.928   0.458
# 1  4xhsWYTOGcal8zt0J161CU  Lovin On Me  Jack Harlow         0.943   0.558
# 2  3rUGC1vUpkDG9CZFHMur1t       greedy   Tate McRae         0.750   0.733
# 3  4iZ4pt7kvcaH6Yo8UoZ4s2       Snooze          SZA         0.559   0.551
# 4  5mjYQaktjmjcMKcUIcqz4s    Strangers  Kenya Grace         0.628   0.523
#
#    key  loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0   11    -6.751     1       0.1870        0.0175  ...    0.1180    0.242
# 1    2    -4.911     1       0.0568        0.0026  ...    0.0937    0.606
# 2    6    -3.180     0       0.0319        0.2560  ...    0.1140    0.844
# 3    5    -7.231     1       0.1320        0.1410  ...    0.1100    0.392
# 4   11    -8.307     0       0.0946        0.7010  ...    0.2190    0.416
#
#      tempo            type                      id  \
# 0  144.995  audio_features  1a73gcEg6h6Re6hHXoVltJ
# 1  104.983  audio_features  4xhsWYTOGcal8zt0J161CU
# 2  111.018  audio_features  3rUGC1vUpkDG9CZFHMur1t
# 3  143.008  audio_features  4iZ4pt7kvcaH6Yo8UoZ4s2
# 4  169.982  audio_features  5mjYQaktjmjcMKcUIcqz4s
#
#                                     uri  \
# 0  spotify:track:1a73gcEg6h6Re6hHXoVltJ
# 1  spotify:track:4xhsWYTOGcal8zt0J161CU
# 2  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3  spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2
# 4  spotify:track:5mjYQaktjmjcMKcUIcqz4s
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1a73gcEg6h6R...
# 1  https://api.spotify.com/v1/tracks/4xhsWYTOGcal...
# 2  https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 3  https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH...
# 4  https://api.spotify.com/v1/tracks/5mjYQaktjmjc...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1a73...      172138
# 1  https://api.spotify.com/v1/audio-analysis/4xhs...      138411
# 2  https://api.spotify.com/v1/audio-analysis/3rUG...      131872
# 3  https://api.spotify.com/v1/audio-analysis/4iZ4...      201800
# 4  https://api.spotify.com/v1/audio-analysis/5mjY...      172965
#
#    time_signature
# 0               4
# 1               4
# 2               1
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Dropping irrelavant columns

# %%
df.columns
# Out:
# Index(['track_ids', 'track_name', 'artists', 'danceability', 'energy', 'key',
#        'loudness', 'mode', 'speechiness', 'acousticness', 'instrumentalness',
#        'liveness', 'valence', 'tempo', 'type', 'id', 'uri', 'track_href',
#        'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
df.drop(['id','track_href','analysis_url'],axis=1,inplace=True)
df.head()
# Out:
#                 track_ids   track_name      artists  danceability  energy  \
# 0  1a73gcEg6h6Re6hHXoVltJ         FTCU  Nicki Minaj         0.928   0.458
# 1  4xhsWYTOGcal8zt0J161CU  Lovin On Me  Jack Harlow         0.943   0.558
# 2  3rUGC1vUpkDG9CZFHMur1t       greedy   Tate McRae         0.750   0.733
# 3  4iZ4pt7kvcaH6Yo8UoZ4s2       Snooze          SZA         0.559   0.551
# 4  5mjYQaktjmjcMKcUIcqz4s    Strangers  Kenya Grace         0.628   0.523
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   11    -6.751     1       0.1870        0.0175          0.000446    0.1180
# 1    2    -4.911     1       0.0568        0.0026          0.000002    0.0937
# 2    6    -3.180     0       0.0319        0.2560          0.000000    0.1140
# 3    5    -7.231     1       0.1320        0.1410          0.000000    0.1100
# 4   11    -8.307     0       0.0946        0.7010          0.002740    0.2190
#
#    valence    tempo            type                                   uri  \
# 0    0.242  144.995  audio_features  spotify:track:1a73gcEg6h6Re6hHXoVltJ
# 1    0.606  104.983  audio_features  spotify:track:4xhsWYTOGcal8zt0J161CU
# 2    0.844  111.018  audio_features  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 3    0.392  143.008  audio_features  spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2
# 4    0.416  169.982  audio_features  spotify:track:5mjYQaktjmjcMKcUIcqz4s
#
#    duration_ms  time_signature
# 0       172138               4
# 1       138411               4
# 2       131872               1
# 3       201800               4
# 4       172965               4

# %%
df.drop(['type'],inplace=True,axis=1)
df.head()
# Out:
#                 track_ids   track_name      artists  danceability  energy  \
# 0  1a73gcEg6h6Re6hHXoVltJ         FTCU  Nicki Minaj         0.928   0.458
# 1  4xhsWYTOGcal8zt0J161CU  Lovin On Me  Jack Harlow         0.943   0.558
# 2  3rUGC1vUpkDG9CZFHMur1t       greedy   Tate McRae         0.750   0.733
# 3  4iZ4pt7kvcaH6Yo8UoZ4s2       Snooze          SZA         0.559   0.551
# 4  5mjYQaktjmjcMKcUIcqz4s    Strangers  Kenya Grace         0.628   0.523
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0   11    -6.751     1       0.1870        0.0175          0.000446    0.1180
# 1    2    -4.911     1       0.0568        0.0026          0.000002    0.0937
# 2    6    -3.180     0       0.0319        0.2560          0.000000    0.1140
# 3    5    -7.231     1       0.1320        0.1410          0.000000    0.1100
# 4   11    -8.307     0       0.0946        0.7010          0.002740    0.2190
#
#    valence    tempo                                   uri  duration_ms  \
# 0    0.242  144.995  spotify:track:1a73gcEg6h6Re6hHXoVltJ       172138
# 1    0.606  104.983  spotify:track:4xhsWYTOGcal8zt0J161CU       138411
# 2    0.844  111.018  spotify:track:3rUGC1vUpkDG9CZFHMur1t       131872
# 3    0.392  143.008  spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2       201800
# 4    0.416  169.982  spotify:track:5mjYQaktjmjcMKcUIcqz4s       172965
#
#    time_signature
# 0               4
# 1               4
# 2               1
# 3               4
# 4               4

# %% [markdown]
# ## Packaging it into a csv file

# %%
df.to_csv('spotifytrackinfo.csv')
