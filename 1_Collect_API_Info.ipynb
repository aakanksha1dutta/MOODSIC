# %% [markdown]
# # Collecting Information and Audio Features into a Dataframe

# %% [markdown]
# ## Importing Libaries

# %% [markdown]
# First we import the libraries necessary for using the Spotify API. Fortunately, Spotify has created an API wrapper called `spotipy` which allows us to interact with their API from a top level.
#
# We have two options for interacting with their API: Authorization Flow and Client Credentials. The Authorization flow is used when we need personal information from a Spotify user like their playlists, likes etc. Client Credentials flow is used to pull general information about Spotify's tracks, playlists etc. We will use the _Client Credentials_ flow.

# %%
import os
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv, dotenv_values

# %% [markdown]
# The dotenv library helps us load our environment variables. You can create your environment variables in a `.env` file.

# %% [markdown]
# Now, we have created a `.env` file in our local machines which has our API information like Client_ID, Client_Secret and Redirect_URL. You can create a similar file in the same directory that has this file. The template for the file is given below for your convenience. Save the file as `.env`
#
# ```
#     CLIENT_ID="your_client_id_here"
#     CLIENT_SECRET="your_client_secret_here"
#     REDIRECT_URL="your_redirect_url_here"
#
# ```

# %% [markdown]
# ## Loading environment variables and storing them

# %%
load_dotenv()
# Out:
# True

# %%
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")
redirect_url = os.getenv("REDIRECT_URL")

# %% [markdown]
# ## Creating an API session

# %%
auth_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# ## Extracting information from the API

# %% [markdown]
# - First we build a dataframe to train our model on. We can do this by taking curated playlists from Spotify with pre-assigned mood labels and classify them according to our labels.
#
# - We will use 4 mood labels : `Happy`, `Sad`, `Enegetic` and `Calm`
#
# - Second, we will also pull top hits songs from the Top Hits playlists to test our model on. Thus, the goal of the project is to classify mood for what the general public likes.

# %% [markdown]
# ### Creating our DataFrame for building our model.

# %%
#we are using playlists from two categories. 
#found URI of specific mood playlists from mood based playlists
happy_playlists = [\
    '37i9dQZF1DX9XIFQuFvzM4','37i9dQZF1DX8Dc28snyWrn','37i9dQZF1DWYBO1MoTDhZI','37i9dQZF1DX1BzILRveYHb']
sad_playlists = [\
    '37i9dQZF1DWSqBruwoIXkA','37i9dQZF1DX9LT7r8qPxfa','37i9dQZF1DWZrBs4FjpxlE','37i9dQZF1DWW2hj3ZtMbuO']
calm_playlists = [\
    '37i9dQZF1DX889U0CL85jj','37i9dQZF1DX6tTW0xDxScH','37i9dQZF1DWUJrRlgpYslH','37i9dQZF1DX17TxDoLeXxl']
energetic_playlists = [\
    '37i9dQZF1DXa2PvUpywmrr','37i9dQZF1DXaXB8fQg7xif','37i9dQZF1DXa90jZU6E5GN','37i9dQZF1DX0u6E5bcKUrV']

# %% [markdown]
# Since there is a limit in Spotify WEB API for the number of requests, we are better off first collecting all the track ids in a single list.
# Then we can partiton it into sublists with 100 track ids (we are allowed to fetch features for a max of 100 ids at a time). This will allow us to use a single request for multiple track ids.

# %%
#extract songs from a playlist and return a list of rows that can be inserted into a dataframe
def get_playlist_tracks(playlist_id):
    track_ids = []
    track_names =[]
    track_artists = []
    tracks = sp.playlist_tracks(playlist_id)['items']
    for track in tracks:
        track_ids.append(track['track']['id'])
        track_names.append(track['track']['name'])
        track_artists.append(track['track']['artists'])
    return track_ids, track_names, track_artists
        
#extract songs from all playlist 
def extract_track_ids(playlist_lists):
    all_track_ids = []
    all_track_names = []
    all_track_artists = []
    for playlist in playlist_lists:
        track_ids, track_names, track_artists = get_playlist_tracks(playlist)
        all_track_ids.extend(track_ids)
        all_track_names.extend(track_names)
        all_track_artists.extend(track_artists)
        
    return all_track_ids, all_track_names, all_track_artists

#partition function
def partition(lst, size):
    split = [lst[i:i+size] for i in range(0,len(lst),size)]
    return split

# %%
happy_track_ids, happy_track_names, happy_track_artists = extract_track_ids(happy_playlists)
sad_track_ids, sad_track_names, sad_track_artists = extract_track_ids(sad_playlists)
energetic_track_ids, energetic_track_names, energetic_track_artists = extract_track_ids(energetic_playlists)
calm_track_ids, calm_track_names, calm_track_artists = extract_track_ids(calm_playlists)

# %%
#since we can only collect audio features of 100 tracks at a time, we should check the length of the the lists that we have
print("happy:", len(happy_track_names))
print('sad:', len(sad_track_names))
print("calm:", len(calm_track_names))
print('energetic:', len(energetic_track_names))
# Out:
# happy: 305
# sad: 325
# calm: 400
# energetic: 390

# %%
def get_features(track_ids):
    part = partition(track_ids,100) #list of partitioned tracks
    audio_features = []
    for p in part:
        audio_features.extend(sp.audio_features(p))
    return audio_features

# %%
happy_features = get_features(happy_track_ids)
sad_features = get_features(sad_track_ids)
calm_features = get_features(calm_track_ids)
energetic_features = get_features(energetic_track_ids)

# %% [markdown]
# _We also need to parse the artists so that we only include the first artist._

# %%
total_artists = (happy_track_artists + sad_track_artists + calm_track_artists + energetic_track_artists)

# %%
first_artist = []
for i in range(0,len(total_artists)):
    first_artist.append(total_artists[i][0]['name'])

# %%
#combining everything into singular lists
track_name = happy_track_names + sad_track_names + calm_track_names + energetic_track_names
track_id = happy_track_ids + sad_track_ids + calm_track_ids + energetic_track_ids
audio_features = happy_features + sad_features + calm_features + energetic_features

# %%
#Labeling our data. Important to maintain the order!!
mood = ['happy']*len(happy_track_ids) + ['sad']*len(sad_track_ids) + ['calm']*len(calm_track_ids) + ['energetic']*len(energetic_track_ids)
mood
# Out:
# ['happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'happy',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'sad',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  'calm',
#  ...]

# %%
#checking if all lengths are same
print("No of artists: ", len(first_artist))
print("No. of track names: ", len(track_name))
print("No of track ids: ", len(track_id))
print("No. of tracks with audio features: ", len(audio_features))
print("No. of mood labels: ", len(mood))
# Out:
# No of artists:  1420
# No. of track names:  1420
# No of track ids:  1420
# No. of tracks with audio features:  1420
# No. of mood labels:  1420

# %% [markdown]
# ### All seem to be well. We can now collect it into a Pandas dataframe.

# %% [markdown]
# ## Collecting extracted information in a Pandas dataframe

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(audio_features)
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.663   0.600    7   -10.870     1       0.0320         0.430
# 1         0.527   0.415    4   -11.451     0       0.1220         0.457
# 2         0.572   0.418    0   -10.738     1       0.0349         0.635
# 3         0.769   0.367    2   -11.226     1       0.0312         0.684
# 4         0.650   0.306    9    -9.443     1       0.0393         0.570
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1840    0.800  129.991  audio_features
# 1          0.000017    0.1170    0.515   78.169  audio_features
# 2          0.000000    0.0961    0.694  104.566  audio_features
# 3          0.000016    0.0810    0.535  103.621  audio_features
# 4          0.000007    0.0707    0.605  118.068  audio_features
#
#                        id                                   uri  \
# 0  7tqhbajSfrz2F7E1Z75ASX  spotify:track:7tqhbajSfrz2F7E1Z75ASX
# 1  1k1Bqnv2R0uJXQN4u6LKYt  spotify:track:1k1Bqnv2R0uJXQN4u6LKYt
# 2  745H5CctFr12Mo7cqa1BMH  spotify:track:745H5CctFr12Mo7cqa1BMH
# 3  3zBhihYUHBmGd2bcQIobrF  spotify:track:3zBhihYUHBmGd2bcQIobrF
# 4  3SdTKo2uVsxFblQjpScoHy  spotify:track:3SdTKo2uVsxFblQjpScoHy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7tqhbajSfrz2...
# 1  https://api.spotify.com/v1/tracks/1k1Bqnv2R0uJ...
# 2  https://api.spotify.com/v1/tracks/745H5CctFr12...
# 3  https://api.spotify.com/v1/tracks/3zBhihYUHBmG...
# 4  https://api.spotify.com/v1/tracks/3SdTKo2uVsxF...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7tqh...       151667
# 1  https://api.spotify.com/v1/audio-analysis/1k1B...       125093
# 2  https://api.spotify.com/v1/audio-analysis/745H...       165000
# 3  https://api.spotify.com/v1/audio-analysis/3zBh...       163756
# 4  https://api.spotify.com/v1/audio-analysis/3SdT...       180056
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
#adding other columns
df.insert(loc=0, column='track_id', value=track_id)
df.insert(loc=1, column='track_name', value=track_name)
df.insert(loc=2, column='first_artist', value=first_artist)
df['mood'] = mood
df.head()
# Out:
#                  track_id                        track_name     first_artist  \
# 0  7tqhbajSfrz2F7E1Z75ASX     Ain't No Mountain High Enough      Marvin Gaye
# 1  1k1Bqnv2R0uJXQN4u6LKYt                 Ain't No Sunshine     Bill Withers
# 2  745H5CctFr12Mo7cqa1BMH                           My Girl  The Temptations
# 3  3zBhihYUHBmGd2bcQIobrF  (Sittin' On) the Dock of the Bay     Otis Redding
# 4  3SdTKo2uVsxFblQjpScoHy                       Stand by Me      Ben E. King
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  ...  \
# 0         0.663   0.600    7   -10.870     1       0.0320         0.430  ...
# 1         0.527   0.415    4   -11.451     0       0.1220         0.457  ...
# 2         0.572   0.418    0   -10.738     1       0.0349         0.635  ...
# 3         0.769   0.367    2   -11.226     1       0.0312         0.684  ...
# 4         0.650   0.306    9    -9.443     1       0.0393         0.570  ...
#
#    valence    tempo            type                      id  \
# 0    0.800  129.991  audio_features  7tqhbajSfrz2F7E1Z75ASX
# 1    0.515   78.169  audio_features  1k1Bqnv2R0uJXQN4u6LKYt
# 2    0.694  104.566  audio_features  745H5CctFr12Mo7cqa1BMH
# 3    0.535  103.621  audio_features  3zBhihYUHBmGd2bcQIobrF
# 4    0.605  118.068  audio_features  3SdTKo2uVsxFblQjpScoHy
#
#                                     uri  \
# 0  spotify:track:7tqhbajSfrz2F7E1Z75ASX
# 1  spotify:track:1k1Bqnv2R0uJXQN4u6LKYt
# 2  spotify:track:745H5CctFr12Mo7cqa1BMH
# 3  spotify:track:3zBhihYUHBmGd2bcQIobrF
# 4  spotify:track:3SdTKo2uVsxFblQjpScoHy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7tqhbajSfrz2...
# 1  https://api.spotify.com/v1/tracks/1k1Bqnv2R0uJ...
# 2  https://api.spotify.com/v1/tracks/745H5CctFr12...
# 3  https://api.spotify.com/v1/tracks/3zBhihYUHBmG...
# 4  https://api.spotify.com/v1/tracks/3SdTKo2uVsxF...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7tqh...      151667
# 1  https://api.spotify.com/v1/audio-analysis/1k1B...      125093
# 2  https://api.spotify.com/v1/audio-analysis/745H...      165000
# 3  https://api.spotify.com/v1/audio-analysis/3zBh...      163756
# 4  https://api.spotify.com/v1/audio-analysis/3SdT...      180056
#
#   time_signature   mood
# 0              4  happy
# 1              4  happy
# 2              4  happy
# 3              4  happy
# 4              4  happy
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Dropping irrelavant columns

# %%
df.columns
# Out:
# Index(['track_id', 'track_name', 'first_artist', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature', 'mood'],
#       dtype='object')

# %%
df.drop(['id','track_href','analysis_url'],axis=1,inplace=True)
df.head()
# Out:
#                  track_id                        track_name     first_artist  \
# 0  7tqhbajSfrz2F7E1Z75ASX     Ain't No Mountain High Enough      Marvin Gaye
# 1  1k1Bqnv2R0uJXQN4u6LKYt                 Ain't No Sunshine     Bill Withers
# 2  745H5CctFr12Mo7cqa1BMH                           My Girl  The Temptations
# 3  3zBhihYUHBmGd2bcQIobrF  (Sittin' On) the Dock of the Bay     Otis Redding
# 4  3SdTKo2uVsxFblQjpScoHy                       Stand by Me      Ben E. King
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.663   0.600    7   -10.870     1       0.0320         0.430
# 1         0.527   0.415    4   -11.451     0       0.1220         0.457
# 2         0.572   0.418    0   -10.738     1       0.0349         0.635
# 3         0.769   0.367    2   -11.226     1       0.0312         0.684
# 4         0.650   0.306    9    -9.443     1       0.0393         0.570
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1840    0.800  129.991  audio_features
# 1          0.000017    0.1170    0.515   78.169  audio_features
# 2          0.000000    0.0961    0.694  104.566  audio_features
# 3          0.000016    0.0810    0.535  103.621  audio_features
# 4          0.000007    0.0707    0.605  118.068  audio_features
#
#                                     uri  duration_ms  time_signature   mood
# 0  spotify:track:7tqhbajSfrz2F7E1Z75ASX       151667               4  happy
# 1  spotify:track:1k1Bqnv2R0uJXQN4u6LKYt       125093               4  happy
# 2  spotify:track:745H5CctFr12Mo7cqa1BMH       165000               4  happy
# 3  spotify:track:3zBhihYUHBmGd2bcQIobrF       163756               4  happy
# 4  spotify:track:3SdTKo2uVsxFblQjpScoHy       180056               4  happy

# %%
df.drop(['type'],inplace=True,axis=1)
df.head()
# Out:
#                  track_id                        track_name     first_artist  \
# 0  7tqhbajSfrz2F7E1Z75ASX     Ain't No Mountain High Enough      Marvin Gaye
# 1  1k1Bqnv2R0uJXQN4u6LKYt                 Ain't No Sunshine     Bill Withers
# 2  745H5CctFr12Mo7cqa1BMH                           My Girl  The Temptations
# 3  3zBhihYUHBmGd2bcQIobrF  (Sittin' On) the Dock of the Bay     Otis Redding
# 4  3SdTKo2uVsxFblQjpScoHy                       Stand by Me      Ben E. King
#
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.663   0.600    7   -10.870     1       0.0320         0.430
# 1         0.527   0.415    4   -11.451     0       0.1220         0.457
# 2         0.572   0.418    0   -10.738     1       0.0349         0.635
# 3         0.769   0.367    2   -11.226     1       0.0312         0.684
# 4         0.650   0.306    9    -9.443     1       0.0393         0.570
#
#    instrumentalness  liveness  valence    tempo  \
# 0          0.000000    0.1840    0.800  129.991
# 1          0.000017    0.1170    0.515   78.169
# 2          0.000000    0.0961    0.694  104.566
# 3          0.000016    0.0810    0.535  103.621
# 4          0.000007    0.0707    0.605  118.068
#
#                                     uri  duration_ms  time_signature   mood
# 0  spotify:track:7tqhbajSfrz2F7E1Z75ASX       151667               4  happy
# 1  spotify:track:1k1Bqnv2R0uJXQN4u6LKYt       125093               4  happy
# 2  spotify:track:745H5CctFr12Mo7cqa1BMH       165000               4  happy
# 3  spotify:track:3zBhihYUHBmGd2bcQIobrF       163756               4  happy
# 4  spotify:track:3SdTKo2uVsxFblQjpScoHy       180056               4  happy

# %% [markdown]
# ## Packaging it into a csv file

# %%
df.to_csv('spotifytrackinfo.csv')

# %% [markdown]
# ### Following the same steps, we create a toplist dataset to use our model on

# %% [markdown]
# Here we are looking at a the Billboard Year End Hot 100 Chart. There is a spotify playlist created around the same which we will use.

# %%
ids, names, artists = get_playlist_tracks('7CxLCjNsxPdZbSmc5gbYJN')
first_artist_ye = []
for i in range(0,len(artists)):
    first_artist_ye.append(artists[i][0]['name'])
audio_features_fe = sp.audio_features(ids)

# %%
year_end_df = pd.DataFrame(audio_features_fe)
year_end_df.insert(loc=0, column='track_id', value=ids)
year_end_df.insert(loc=1, column='track_name', value=names)
year_end_df.insert(loc=2, column='first_artist', value=first_artist_ye)
year_end_df.head()
# Out:
#                  track_id                              track_name  \
# 0  7K3BhSpAxZBznislvUMVtn                              Last Night
# 1  0yLdNVWF3Srea0uzk55zFn                                 Flowers
# 2  3OHfY25tqY28d16oZczHc8                               Kill Bill
# 3  0V3wPSX9ygBnCm8psDIegu                               Anti-Hero
# 4  2dHHgzDwk4BJdRwy9uXhTO  Creepin' (with The Weeknd & 21 Savage)
#
#     first_artist  danceability  energy  key  loudness  mode  speechiness  \
# 0  Morgan Wallen         0.492   0.675    6    -5.456     1       0.0389
# 1    Miley Cyrus         0.707   0.681    0    -4.325     1       0.0668
# 2            SZA         0.644   0.728    8    -5.750     1       0.0351
# 3   Taylor Swift         0.637   0.643    4    -6.571     1       0.0519
# 4   Metro Boomin         0.715   0.620    1    -6.005     0       0.0484
#
#    acousticness  ...  liveness  valence    tempo            type  \
# 0        0.4670  ...    0.1420    0.478  203.759  audio_features
# 1        0.0632  ...    0.0322    0.646  117.999  audio_features
# 2        0.0543  ...    0.1610    0.430   88.993  audio_features
# 3        0.1300  ...    0.1420    0.533   97.008  audio_features
# 4        0.4170  ...    0.0822    0.172   97.950  audio_features
#
#                        id                                   uri  \
# 0  7K3BhSpAxZBznislvUMVtn  spotify:track:7K3BhSpAxZBznislvUMVtn
# 1  0yLdNVWF3Srea0uzk55zFn  spotify:track:0yLdNVWF3Srea0uzk55zFn
# 2  3OHfY25tqY28d16oZczHc8  spotify:track:3OHfY25tqY28d16oZczHc8
# 3  0V3wPSX9ygBnCm8psDIegu  spotify:track:0V3wPSX9ygBnCm8psDIegu
# 4  2dHHgzDwk4BJdRwy9uXhTO  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/7K3BhSpAxZBz...
# 1  https://api.spotify.com/v1/tracks/0yLdNVWF3Sre...
# 2  https://api.spotify.com/v1/tracks/3OHfY25tqY28...
# 3  https://api.spotify.com/v1/tracks/0V3wPSX9ygBn...
# 4  https://api.spotify.com/v1/tracks/2dHHgzDwk4BJ...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/7K3B...      163855
# 1  https://api.spotify.com/v1/audio-analysis/0yLd...      200455
# 2  https://api.spotify.com/v1/audio-analysis/3OHf...      153947
# 3  https://api.spotify.com/v1/audio-analysis/0V3w...      200690
# 4  https://api.spotify.com/v1/audio-analysis/2dHH...      221520
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4
#
# [5 rows x 21 columns]

# %%
year_end_df.to_csv('bbyearend.csv')
